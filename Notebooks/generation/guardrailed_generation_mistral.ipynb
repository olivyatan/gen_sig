# %% [markdown]
# # Setup

# %%
base_path_kry = '/home/mmandelbrod/repositories/'
base_path_mac = '/Users/mmandelbrod/workspace/'
import sys
import os

tmp = !hostname
if tmp[0].startswith('krylov'):
    on_kry = True
else: 
    on_kry = False
    
base_path = base_path_kry if on_kry else base_path_mac

print(base_path)

sys.path.append(base_path)
sys.path.append(os.path.join(base_path, 'signals/'))
# sys.path.append(os.path.join(base_path, 'signals/src'))
sys.path.append(os.path.join(base_path, 'generative-signals/'))
sys.path.append(os.path.join(base_path, 'generative-signals/src'))
sys.path.append(os.path.join(base_path, 'generative-signals/dev/generation'))
sys.path.append(os.path.join(base_path, 'signals/workflows/pipelines/'))
sys.path.append(os.path.join(base_path, 'signals/workflows/global_utils/'))
sys.path.append(os.path.join(base_path, 'signals/workflows'))
sys.path.append(os.path.join(base_path, 'matans_sandbox/utils'))
sys.path.append(os.path.join(base_path, 'gpt_call_async'))

os.chdir(os.path.join(base_path,'generative-signals'))
print(f"curr dir: {os.getcwd()}")
# Out:
# /home/mmandelbrod/repositories/
# curr dir: /home/mmandelbrod/repositories/generative-signals

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import os
import sys
import base64
from bs4 import BeautifulSoup
import re
import json
import os
from datetime import datetime
from functools import reduce
from typing import List
import gzip
import numpy as np
from generation.sigs_gen import *
from data_extraction.extraction_funcs import *
from generation.generators import gpt_generator, mistral_generator
os.getcwd()
# Out:
# '/home/mmandelbrod/repositories/generative-signals'

# %% [markdown]
# ## Importlib

# %%
import importlib
def refresh_module(module_name):
    try:
        module = importlib.import_module(module_name)
        importlib.reload(module)
        module = importlib.import_module(module_name)
        globals().update(module.__dict__)
    except ImportError as e:
        print(f"Error importing module {module_name}: {e}")
        return None

# %%
refresh_module('data_extraction.extraction_funcs')

# %%
import data_extraction.extraction_funcs
importlib.reload(data_extraction.extraction_funcs)
import data_extraction.extraction_funcs
from data_extraction.extraction_funcs import *


import generation.sigs_gen
importlib.reload(generation.sigs_gen)
import generation.sigs_gen
from generation.sigs_gen import *

import generation.generators.gpt_generator
importlib.reload(generation.sigs_gen)
import generation.sigs_gen
from generation.sigs_gen import *

import generation.generators.base_sigs_generator
importlib.reload(generation.generators.base_sigs_generator)
import generation.generators.base_sigs_generator
from generation.generators.base_sigs_generator import *

refresh_module('generation.generators.base_sigs_generator')
refresh_module('generation.generators.gpt_generator')
refresh_module('generation.generators.mistral_generator')

# from generation.generators import gpt_generator, mistral_generator

# %%
post_generation_amendments??
# Out:
# Object `post_generation_amendments` not found.

# %%
# forbidden_set = set(['shipping', 'delivery', 'price', 'condition', "shipment", "cheap", "free", "fee",
#                    "discount", "sale", "offer", "promotion", "promo", "buy", "purchase", "order",
#                    "shop", "store", "online", "website", "web", "link", "click", "here", "visit",
#                    "check", "out", "more", "info", "information", "details", "contact", "us", "email",
#                    "phone", "call", "whatsapp", "telegram", "viber", "facebook", "instagram", "twitter",
#                    "youtube", "pinterest", "linkedin", "tiktok", "snapchat", "whatsapp", "viber", "telegram",
#                    "contact", "address", "location", "map", "direction", "route", "how", "where", "when",
#                    "what", "which", "who", "why", "question", "answer", "faq", "frequently", "asked",
#                    "question", "help", "support", "service", "customer", "client", "consumer", "buyer",
#                    "seller", "vendor", "supplier", "manufacturer", "distributor", "retailer", "reseller",
#                    "wholesaler", "dropshipper", "dropshipping", "dropship", "drop", "contact", "address",
#                    "limited edition", "limited", "edition", "exclusive", "exclusively", "exclusive offer",
#                    "original", "authentic", "authenticity", "genuine", "real", "official", "officially",
#                    "used", "second hand", "secondhand", "pre-owned", "preowned", "pre owned", "preowned",
#                    "unbranded", "warranty", "guarantee", "return", "refund", "exchange", "policy", "terms",
#                    "new", "brand new", "brandnew", "brand-new", "used", "second hand", "secondhand",
#                    "old", "vintage", "antique", "classic", "retro", "Nan", "nan", "N/A", "n/a", "none",
#                    "unknown", "money", "cash", "payment", "pay", "paying", "paid", "payable", "priceless",
#                    "trust", "trusted", "reliable", "reliability", "safe", "safety", "secure", "security"]).union(\
#     set(['shipping', 'delivery', 'price', 'condition', "shipment", "cheap", "free",
#                    "discount", "sale", "offer", "promotion", "promo", "buy", "purchase", "order",
#                    "shop", "store", "online", "website", "web", "link", "click", "here", "visit",
#                    "check", "out", "more", "info", "information", "details", "contact", "us", "email",
#                    "phone", "call", "whatsapp", "telegram", "viber", "facebook", "instagram", "twitter",
#                    "youtube", "pinterest", "linkedin", "tiktok", "snapchat", "whatsapp", "viber", "telegram",
#                    "contact", "address", "location", "map", "direction", "route", "how", "where", "when",
#                    "what", "which", "who", "why", "question", "answer", "faq", "frequently", "asked",
#                    "question", "help", "support", "service", "customer", "client", "consumer", "buyer",
#                    "seller", "vendor", "supplier", "manufacturer", "distributor", "retailer", "reseller",
#                    "wholesaler", "dropshipper", "dropshipping", "dropship", "drop", "contact", "address",
#                    "limited edition", "limited", "edition", "exclusive", "exclusively", "exclusive offer",
#                    "original", "authentic", "authenticity", "genuine", "real", "official", "officially",
#                    "used", "second hand", "secondhand", "pre-owned", "preowned", "pre owned", "preowned"])).union([\
#                     'vintage', 'rare', 'genuine', 'high', 'quality', 'guaranteed', 'guarantee', 'universal', 'fitment', 
#                     'fit', 'fitted', 'authorized', 'dealer', 'warranty', 'signed', 'signature' ])
# list(forbidden_set)
# Out:
# ['return',
#  'limited edition',
#  'sale',
#  'dealer',
#  'telegram',
#  'none',
#  'shipment',
#  'offer',
#  'used',
#  'unbranded',
#  'email',
#  'trust',
#  'payable',
#  'buy',
#  'shop',
#  'information',
#  'instagram',
#  'N/A',
#  'authentic',
#  'preowned',
#  'signature',
#  'direction',
#  'consumer',
#  'visit',
#  'us',
#  'guarantee',
#  'free',
#  'universal',
#  'help',
#  'exclusive',
#  'fit',
#  'trusted',
#  'reliability',
#  'real',
#  'reliable',
#  'seller',
#  'supplier',
#  'policy',
#  'shipping',
#  'brand-new',
#  'quality',
#  'drop',
#  'viber',
#  'payment',
#  'which',
#  'priceless',
#  'when',
#  'dropshipper',
#  'web',
#  'retro',
#  'security',
#  'second hand',
#  'youtube',
#  'website',
#  'distributor',
#  'cash',
#  'pay',
#  'paid',
#  'asked',
#  'cheap',
#  'service',
#  'rare',
#  'buyer',
#  'how',
#  'secure',
#  'guaranteed',
#  'fee',
#  'pre owned',
#  'map',
#  'here',
#  'new',
#  'facebook',
#  'limited',
#  'vendor',
# ...

# %% [markdown]
# # Filtering Version 1 (git: filtering_version_1)

# %% [markdown]
# ## Collectibles

# %%
collct_df = pd.read_csv('data/Datasets/collct_pna_09_17/gen_collct_us_oct_gpt_mistral_with_img_url.csv', index_col=0)
collct_df = collct_df.drop(columns=['gen_text_mistral', 'gen_sig_mistral', 'gen_text_gpt', 'gen_sig_gpt'])
collct_df['desc'] = collct_df['desc'].astype(str)
collct_df['title'] = collct_df['title'].astype(str)
collct_df['aspects'] = collct_df['aspects'].apply(lambda s : ast.literal_eval(s))
collct_df
# Out:
#            item_id                                          item_desc  \
# 0     123979599749  PGZvbnQgcndyPSIxIiBzdHlsZT0iZm9udC1mYW1pbHk6IE...
# 1     134658435740  PHN0eWxlPmltZ3ttYXgtd2lkdGg6MTAwJX08L3N0eWxlPj...
# 2     145560028063  PGI+UExFQVNFIExPT0sgQVQgVEhFIENPTkRJVElPTiBPRi...
# 3     156013659941  PHA+MTk3MiBUb3BwcyAtIFRvbnkgUGVyZXogLSAgIzgwIC...
# 4     166873659153  PHAgZGlyPSJsdHIiIHN0eWxlPSJtYXJnaW4tdG9wOjA7IG...
# ...            ...                                                ...
# 4984  353816745693  PHAgZGlyPSJsdHIiIHN0eWxlPSJtYXJnaW4tdG9wOjA7IG...
# 4985  354114504594  PGZvbnQgcndyPSIxIiBzaXplPSI0IiBzdHlsZT0iZm9udC...
# 4986  354593615047  PCFET0NUWVBFIGh0bWw+CjxodG1sIGxhbmc9IiI+Cgo8aG...
# 4987  395538561456  SmFwYW5lc2UgYW5pbWUgS2lubmlrdW1hbiBmaWd1cmUgUm...
# 4988  405173165585  PGRpdiBzdHlsZT0iIiBmYWNlPSJUcmVidWNoZXQgTVMiPj...
#
#                                                   title SUBTITLE  \
# ...

# %%
collct_df_amended = post_extraction_amendments(collct_df)
collct_df_amended
# Out:
#            item_id                                          item_desc  \
# 0     123979599749  PGZvbnQgcndyPSIxIiBzdHlsZT0iZm9udC1mYW1pbHk6IE...
# 1     134658435740  PHN0eWxlPmltZ3ttYXgtd2lkdGg6MTAwJX08L3N0eWxlPj...
# 2     145560028063  PGI+UExFQVNFIExPT0sgQVQgVEhFIENPTkRJVElPTiBPRi...
# 3     156013659941  PHA+MTk3MiBUb3BwcyAtIFRvbnkgUGVyZXogLSAgIzgwIC...
# 4     166873659153  PHAgZGlyPSJsdHIiIHN0eWxlPSJtYXJnaW4tdG9wOjA7IG...
# ...            ...                                                ...
# 4984  353816745693  PHAgZGlyPSJsdHIiIHN0eWxlPSJtYXJnaW4tdG9wOjA7IG...
# 4985  354114504594  PGZvbnQgcndyPSIxIiBzaXplPSI0IiBzdHlsZT0iZm9udC...
# 4986  354593615047  PCFET0NUWVBFIGh0bWw+CjxodG1sIGxhbmc9IiI+Cgo8aG...
# 4987  395538561456  SmFwYW5lc2UgYW5pbWUgS2lubmlrdW1hbiBmaWd1cmUgUm...
# 4988  405173165585  PGRpdiBzdHlsZT0iIiBmYWNlPSJUcmVidWNoZXQgTVMiPj...
#
#                                                   title SUBTITLE  \
# ...

# %%
collct_df_amended.to_csv('data/Datasets/collct_pna_09_17/collectb_us_oct_filt_tokens.csv')

# %%
collct_df_amended = pd.read_csv('data/Datasets/collct_pna_09_17/collectb_us_oct_filt_tokens.csv', index_col = 0)
# collct_df_amended

# %%
outfile = 'collct_us_filt_tokens_mistral_cont'
collct_df_with_sigs = await generate_signals_per_item(collct_df_amended[3350:], 
                                                      cols_for_prompt=['title_no_forbidden', 'aspects_no_forbidden', 'desc_no_forbidden'], 
                                                      outfile=f'data/Datasets/collct_pna_09_17/{outfile}.jsonl',  model_name='mistral') 
collct_df_with_sigs.to_parquet(f'data/Datasets/collct_pna_09_17/{outfile}.parquet')
# Out:
# 2024-09-14 16:31:51,634 - pykrylov.util.config [MainThread  ] [WARNI]  Add MMS_V1 entry to config clusters; No action needed on users' side
# 2024-09-14 16:31:51,635 - pykrylov.util.config [MainThread  ] [WARNI]  Update MMS_V1 Server to https://krylov-mms.vip.ebay.com and ProxyServer to c2sproxy;No action needed on users' side
# loading configuration file /data/shpx/data/mmandelbrod/.cache/ellement/athena-mvp/Mistral-7B-Instruct-v02/1/config.json
# Model config MistralConfig {
#   "_name_or_path": "/data/shpx/data/mmandelbrod/.cache/ellement/athena-mvp/Mistral-7B-Instruct-v02/1",
#   "architectures": [
#     "MistralForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "head_dim": 128,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 32768,
#   "model_type": "mistral",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
# ...

# %%
collct_df_with_sigs
# Out:
#            item_id                                          item_desc  \
# 3350  176291981592  PGZvbnQgcndyPSIxIiBzdHlsZT0iZm9udC1mYW1pbHk6QX...
# 3351  186169083029  PGgxPjxkaXYgaWQ9InRpdGxlX2ZlYXR1cmVfZGl2IiBjbG...
# 3352  194136606447  PHAgY2xhc3M9Ik1zb05vcm1hbCI+PGIgc3R5bGU9Im1zby...
# 3353  202938099579  PHAgc3R5bGU9Im1hcmdpbjogNXB4IDBweCAwcHggNXB4Oy...
# 3354  203835246917  PHA+R29sZGVuIE1pc3QgVmFzZSBGaW5lIFBvcmNlbGFpbi...
# ...            ...                                                ...
# 4984  353816745693  PHAgZGlyPSJsdHIiIHN0eWxlPSJtYXJnaW4tdG9wOjA7IG...
# 4985  354114504594  PGZvbnQgcndyPSIxIiBzaXplPSI0IiBzdHlsZT0iZm9udC...
# 4986  354593615047  PCFET0NUWVBFIGh0bWw+CjxodG1sIGxhbmc9IiI+Cgo8aG...
# 4987  395538561456  SmFwYW5lc2UgYW5pbWUgS2lubmlrdW1hbiBmaWd1cmUgUm...
# 4988  405173165585  PGRpdiBzdHlsZT0iIiBmYWNlPSJUcmVidWNoZXQgTVMiPj...
#
#                                                   title SUBTITLE  \
# ...

# %% [markdown]
# ## Stitch the two generation pieces

# %%
collct_df_amended
# Out:
#            item_id                                          item_desc  \
# 0     123979599749  PGZvbnQgcndyPSIxIiBzdHlsZT0iZm9udC1mYW1pbHk6IE...
# 1     134658435740  PHN0eWxlPmltZ3ttYXgtd2lkdGg6MTAwJX08L3N0eWxlPj...
# 2     145560028063  PGI+UExFQVNFIExPT0sgQVQgVEhFIENPTkRJVElPTiBPRi...
# 3     156013659941  PHA+MTk3MiBUb3BwcyAtIFRvbnkgUGVyZXogLSAgIzgwIC...
# 4     166873659153  PHAgZGlyPSJsdHIiIHN0eWxlPSJtYXJnaW4tdG9wOjA7IG...
# ...            ...                                                ...
# 4984  353816745693  PHAgZGlyPSJsdHIiIHN0eWxlPSJtYXJnaW4tdG9wOjA7IG...
# 4985  354114504594  PGZvbnQgcndyPSIxIiBzaXplPSI0IiBzdHlsZT0iZm9udC...
# 4986  354593615047  PCFET0NUWVBFIGh0bWw+CjxodG1sIGxhbmc9IiI+Cgo8aG...
# 4987  395538561456  SmFwYW5lc2UgYW5pbWUgS2lubmlrdW1hbiBmaWd1cmUgUm...
# 4988  405173165585  PGRpdiBzdHlsZT0iIiBmYWNlPSJUcmVidWNoZXQgTVMiPj...
#
#                                                   title SUBTITLE  \
# ...

# %%
collct_df_1 = pd.read_json('data/Datasets/collct_pna_09_17/collct_us_filt_tokens_mistral_first_3K.jsonl', lines=True)
collct_df_1
# Out:
#                                                       0
# 0     {\n"characteristic": "English church",\n"expla...
# 1     {"characteristic": "1971 Topps Football", "exp...
# 2     {"characteristic": "2000 winners circle",\n "e...
# 3     {"characteristic": "Major League Baseball (MLB...
# 4     {"characteristic": "12.5\" handle, 15 oz. head...
# ...                                                 ...
# 3345  {"characteristic": "oversized sports trading c...
# 3346  {"characteristic": "uncirculated condition",\n...
# 3347  {"characteristic": "springtime essence", "expl...
# 3348  {"characteristic": "Grilled Riverwalk Royalty"...
# 3349  { "_藏 Власнотие_": "wood material",\n  "explan...
#
# [3350 rows x 1 columns]

# %%
collct_df_with_sigs
# Out:
#            item_id                                          item_desc  \
# 3350  176291981592  PGZvbnQgcndyPSIxIiBzdHlsZT0iZm9udC1mYW1pbHk6QX...
# 3351  186169083029  PGgxPjxkaXYgaWQ9InRpdGxlX2ZlYXR1cmVfZGl2IiBjbG...
# 3352  194136606447  PHAgY2xhc3M9Ik1zb05vcm1hbCI+PGIgc3R5bGU9Im1zby...
# 3353  202938099579  PHAgc3R5bGU9Im1hcmdpbjogNXB4IDBweCAwcHggNXB4Oy...
# 3354  203835246917  PHA+R29sZGVuIE1pc3QgVmFzZSBGaW5lIFBvcmNlbGFpbi...
# ...            ...                                                ...
# 4984  353816745693  PHAgZGlyPSJsdHIiIHN0eWxlPSJtYXJnaW4tdG9wOjA7IG...
# 4985  354114504594  PGZvbnQgcndyPSIxIiBzaXplPSI0IiBzdHlsZT0iZm9udC...
# 4986  354593615047  PCFET0NUWVBFIGh0bWw+CjxodG1sIGxhbmc9IiI+Cgo8aG...
# 4987  395538561456  SmFwYW5lc2UgYW5pbWUgS2lubmlrdW1hbiBmaWd1cmUgUm...
# 4988  405173165585  PGRpdiBzdHlsZT0iIiBmYWNlPSJUcmVidWNoZXQgTVMiPj...
#
#                                                   title SUBTITLE  \
# ...

# %%
len(collct_df_amended) == len(collct_df_1) + len(collct_df_with_sigs)
# Out:
# True

# %%
collct_df_with_sigs
# Out:
#            item_id                                          item_desc  \
# 3350  176291981592  PGZvbnQgcndyPSIxIiBzdHlsZT0iZm9udC1mYW1pbHk6QX...
# 3351  186169083029  PGgxPjxkaXYgaWQ9InRpdGxlX2ZlYXR1cmVfZGl2IiBjbG...
# 3352  194136606447  PHAgY2xhc3M9Ik1zb05vcm1hbCI+PGIgc3R5bGU9Im1zby...
# 3353  202938099579  PHAgc3R5bGU9Im1hcmdpbjogNXB4IDBweCAwcHggNXB4Oy...
# 3354  203835246917  PHA+R29sZGVuIE1pc3QgVmFzZSBGaW5lIFBvcmNlbGFpbi...
# ...            ...                                                ...
# 4984  353816745693  PHAgZGlyPSJsdHIiIHN0eWxlPSJtYXJnaW4tdG9wOjA7IG...
# 4985  354114504594  PGZvbnQgcndyPSIxIiBzaXplPSI0IiBzdHlsZT0iZm9udC...
# 4986  354593615047  PCFET0NUWVBFIGh0bWw+CjxodG1sIGxhbmc9IiI+Cgo8aG...
# 4987  395538561456  SmFwYW5lc2UgYW5pbWUgS2lubmlrdW1hbiBmaWd1cmUgUm...
# 4988  405173165585  PGRpdiBzdHlsZT0iIiBmYWNlPSJUcmVidWNoZXQgTVMiPj...
#
#                                                   title SUBTITLE  \
# ...

# %%
collct_df_amended[:len(collct_df_1)]
# Out:
#            item_id                                          item_desc  \
# 0     123979599749  PGZvbnQgcndyPSIxIiBzdHlsZT0iZm9udC1mYW1pbHk6IE...
# 1     134658435740  PHN0eWxlPmltZ3ttYXgtd2lkdGg6MTAwJX08L3N0eWxlPj...
# 2     145560028063  PGI+UExFQVNFIExPT0sgQVQgVEhFIENPTkRJVElPTiBPRi...
# 3     156013659941  PHA+MTk3MiBUb3BwcyAtIFRvbnkgUGVyZXogLSAgIzgwIC...
# 4     166873659153  PHAgZGlyPSJsdHIiIHN0eWxlPSJtYXJnaW4tdG9wOjA7IG...
# ...            ...                                                ...
# 3345  145957844864  PGZvbnQgcndyPSIxIiBzdHlsZT0iIj48bWV0YSBuYW1lPS...
# 3346  156360598008  PGRpdiBkYXRhLW1hcmtvLWtleT0iQGNvbnRhaW5lciBzMC...
# 3347  156361060939  SW4gdGhlIHllYXIgMjAwMiwgSGFsbG1hcmsgZ2lmdGVkIH...
# 3348  166603861814  PGZvbnQgcndyPSIxIiBzaXplPSI0IiBzdHlsZT0iZm9udC...
# 3349  175655106153  PHA+QXV0aGVudGljIE1pbmlhdHVyZSBXb29kZW4gQ2Fydm...
#
#                                                   title SUBTITLE  \
# ...

# %%
collct_df_with_sigs_1 = collct_df_amended.iloc[:len(collct_df_1)]
collct_df_with_sigs_1['gen_text_mistral'] = collct_df_1[0]
collct_df_with_sigs_1['gen_sig_mistral'] = ''
collct_df_with_sigs_1
# Out:
#            item_id                                          item_desc  \
# 0     123979599749  PGZvbnQgcndyPSIxIiBzdHlsZT0iZm9udC1mYW1pbHk6IE...
# 1     134658435740  PHN0eWxlPmltZ3ttYXgtd2lkdGg6MTAwJX08L3N0eWxlPj...
# 2     145560028063  PGI+UExFQVNFIExPT0sgQVQgVEhFIENPTkRJVElPTiBPRi...
# 3     156013659941  PHA+MTk3MiBUb3BwcyAtIFRvbnkgUGVyZXogLSAgIzgwIC...
# 4     166873659153  PHAgZGlyPSJsdHIiIHN0eWxlPSJtYXJnaW4tdG9wOjA7IG...
# ...            ...                                                ...
# 3345  145957844864  PGZvbnQgcndyPSIxIiBzdHlsZT0iIj48bWV0YSBuYW1lPS...
# 3346  156360598008  PGRpdiBkYXRhLW1hcmtvLWtleT0iQGNvbnRhaW5lciBzMC...
# 3347  156361060939  SW4gdGhlIHllYXIgMjAwMiwgSGFsbG1hcmsgZ2lmdGVkIH...
# 3348  166603861814  PGZvbnQgcndyPSIxIiBzaXplPSI0IiBzdHlsZT0iZm9udC...
# 3349  175655106153  PHA+QXV0aGVudGljIE1pbmlhdHVyZSBXb29kZW4gQ2Fydm...
#
#                                                   title SUBTITLE  \
# ...

# %%
collct_df_with_sigs_1.loc[collct_df_with_sigs_1['gen_sig_mistral'] == '', ['gen_text_mistral', 'gen_sig_mistral']] = collct_df_with_sigs_1.loc[
            collct_df_with_sigs_1['gen_sig_mistral'] == '', 'gen_text_mistral'].apply(
            lambda r: extract_sig_fix(r, ['gen_text_mistral', 'gen_sig_mistral']))
# Out:
# Couldn't find a match to dict string in {"characteristic": "12.5\" handle, 15 oz. head", "explanation": "The product's handle length and head weight provide a perfect balance of power and precision, making it an effective and efficient tool for various hammering tasks."}
# Couldn't find a match to dict string in {"characteristic": "3 1/2\" tall, German origin", "explanation": "The product's small size and German origin suggest it could be a collectible item or a thoughtful gift."}
#
# Reasoning: The product's size and country of origin provide information about its potential value or uniqueness, making it a convincing characteristic for potential buyers.
# Couldn't find a match to dict string in {"characteristic": "Measures 6 3/4\" diameter", "explanation": "This characteristic provides important information about the product's size, which can help potential buyers determine if it will fit their specific needs or preferences."}
# Couldn't find a match to dict string in {
# ...

# %%
collct_df_with_sigs_1
# Out:
#            item_id                                          item_desc  \
# 0     123979599749  PGZvbnQgcndyPSIxIiBzdHlsZT0iZm9udC1mYW1pbHk6IE...
# 1     134658435740  PHN0eWxlPmltZ3ttYXgtd2lkdGg6MTAwJX08L3N0eWxlPj...
# 2     145560028063  PGI+UExFQVNFIExPT0sgQVQgVEhFIENPTkRJVElPTiBPRi...
# 3     156013659941  PHA+MTk3MiBUb3BwcyAtIFRvbnkgUGVyZXogLSAgIzgwIC...
# 4     166873659153  PHAgZGlyPSJsdHIiIHN0eWxlPSJtYXJnaW4tdG9wOjA7IG...
# ...            ...                                                ...
# 3345  145957844864  PGZvbnQgcndyPSIxIiBzdHlsZT0iIj48bWV0YSBuYW1lPS...
# 3346  156360598008  PGRpdiBkYXRhLW1hcmtvLWtleT0iQGNvbnRhaW5lciBzMC...
# 3347  156361060939  SW4gdGhlIHllYXIgMjAwMiwgSGFsbG1hcmsgZ2lmdGVkIH...
# 3348  166603861814  PGZvbnQgcndyPSIxIiBzaXplPSI0IiBzdHlsZT0iZm9udC...
# 3349  175655106153  PHA+QXV0aGVudGljIE1pbmlhdHVyZSBXb29kZW4gQ2Fydm...
#
#                                                   title SUBTITLE  \
# ...

# %%
len(collct_df_with_sigs_1.loc[collct_df_with_sigs_1['gen_sig_mistral'] == ''])
# Out:
# 44

# %%
collct_df_with_sigs_merged = pd.concat([collct_df_with_sigs_1, collct_df_with_sigs], axis=0)
collct_df_with_sigs_merged
# Out:
#            item_id                                          item_desc  \
# 0     123979599749  PGZvbnQgcndyPSIxIiBzdHlsZT0iZm9udC1mYW1pbHk6IE...
# 1     134658435740  PHN0eWxlPmltZ3ttYXgtd2lkdGg6MTAwJX08L3N0eWxlPj...
# 2     145560028063  PGI+UExFQVNFIExPT0sgQVQgVEhFIENPTkRJVElPTiBPRi...
# 3     156013659941  PHA+MTk3MiBUb3BwcyAtIFRvbnkgUGVyZXogLSAgIzgwIC...
# 4     166873659153  PHAgZGlyPSJsdHIiIHN0eWxlPSJtYXJnaW4tdG9wOjA7IG...
# ...            ...                                                ...
# 4984  353816745693  PHAgZGlyPSJsdHIiIHN0eWxlPSJtYXJnaW4tdG9wOjA7IG...
# 4985  354114504594  PGZvbnQgcndyPSIxIiBzaXplPSI0IiBzdHlsZT0iZm9udC...
# 4986  354593615047  PCFET0NUWVBFIGh0bWw+CjxodG1sIGxhbmc9IiI+Cgo8aG...
# 4987  395538561456  SmFwYW5lc2UgYW5pbWUgS2lubmlrdW1hbiBmaWd1cmUgUm...
# 4988  405173165585  PGRpdiBzdHlsZT0iIiBmYWNlPSJUcmVidWNoZXQgTVMiPj...
#
#                                                   title SUBTITLE  \
# ...

# %%
collct_df_with_sigs_merged.to_parquet('data/Datasets/collct_pna_09_17/DFsWithSigs/collct_with_sigs_mistral.parquet')

# %% [markdown]
# ## pna

# %%
pna_df = pd.read_csv('data/Datasets/collct_pna_09_17/gen_collct_us_oct_gpt_mistral_with_img_url.csv', index_col=0)
pna_df = pna_df.drop(columns=['gen_text_mistral', 'gen_sig_mistral', 'gen_text_gpt', 'gen_sig_gpt'])
pna_df['desc'] = pna_df['desc'].astype(str)
pna_df['title'] = pna_df['title'].astype(str)
pna_df['aspects'] = pna_df['aspects'].apply(lambda s : ast.literal_eval(s))
pna_df
# Out:
#            item_id                                          item_desc  \
# 0     123979599749  PGZvbnQgcndyPSIxIiBzdHlsZT0iZm9udC1mYW1pbHk6IE...
# 1     134658435740  PHN0eWxlPmltZ3ttYXgtd2lkdGg6MTAwJX08L3N0eWxlPj...
# 2     145560028063  PGI+UExFQVNFIExPT0sgQVQgVEhFIENPTkRJVElPTiBPRi...
# 3     156013659941  PHA+MTk3MiBUb3BwcyAtIFRvbnkgUGVyZXogLSAgIzgwIC...
# 4     166873659153  PHAgZGlyPSJsdHIiIHN0eWxlPSJtYXJnaW4tdG9wOjA7IG...
# ...            ...                                                ...
# 4984  353816745693  PHAgZGlyPSJsdHIiIHN0eWxlPSJtYXJnaW4tdG9wOjA7IG...
# 4985  354114504594  PGZvbnQgcndyPSIxIiBzaXplPSI0IiBzdHlsZT0iZm9udC...
# 4986  354593615047  PCFET0NUWVBFIGh0bWw+CjxodG1sIGxhbmc9IiI+Cgo8aG...
# 4987  395538561456  SmFwYW5lc2UgYW5pbWUgS2lubmlrdW1hbiBmaWd1cmUgUm...
# 4988  405173165585  PGRpdiBzdHlsZT0iIiBmYWNlPSJUcmVidWNoZXQgTVMiPj...
#
#                                                   title SUBTITLE  \
# ...

# %%
pna_df_amended = post_extraction_amendments(pna_df)

# %%
pna_df.to_csv('data/Datasets/collct_pna_09_17/pna_us_oct_filt_tokens.csv')

# %%
pna_df_amended = pd.read_csv('data/Datasets/collct_pna_09_17/DFsExtractedAmended/pna_us_oct_filt_tokens.csv', index_col=0)
pna_df_amended
# collct_df_amended
# Out:
#            item_id                                          item_desc  \
# 0     133145078392  PGh0bWw+CiAgPGhlYWQ+CiAgICA8bWV0YSBuYW1lPSJ2aW...
# 1     145730116960  PCEtLVBBNF9IVE1MVG9wX0JlZ2luLS0+PGRpdiBjbGFzcz...
# 2     145896526900  PGZyb290ZW1wbGF0ZW5hbWUgZGF0YT0iY3VzdG9tX3RlbX...
# 3     154376682589  CgkJCQkJICA8IURPQ1RZUEUgaHRtbD4KPGh0bWwgbGFuZz...
# 4     156171302116  PCEtLSBIVE1MIC0tPgo8IS0tCkNvcHlyaWdodCDCqTIwMT...
# ...            ...                                                ...
# 4985  393800002843  CgkJCQkJICA8IURPQ1RZUEUgaHRtbD4KPGh0bWwgbGFuZz...
# 4986  395069562156  PCEtLVBBNF9IVE1MVG9wX0JlZ2luLS0+PGRpdiBjbGFzcz...
# 4987  395070130374  PHN0eWxlIHR5cGU9J3RleHQvY3NzJz4KaHRtbCwgYm9keS...
# 4988  403415943912  CgkJCQkJICA8IURPQ1RZUEUgaHRtbD4KPGh0bWwgbGFuZz...
# 4989  404630452043  PGRpdiBzdHlsZT0iZGlzcGxheTogbm9uZTsiPjxoMT5BbG...
#
#                                                   title  \
# 0     jnc 026 black machined face 18x8 5x100 +35 whe...
# ...

# %%
outfile = 'pna_us_filt_tokens_mistral'
pna_df_with_sigs = await generate_signals_per_item(pna_df_amended, 
                                                      cols_for_prompt=['title_no_forbidden', 'aspects_no_forbidden', 'desc_no_forbidden'], 
                                                      outfile=f'data/Datasets/collct_pna_09_17/{outfile}.jsonl',  model_name='mistral') 
pna_df_with_sigs.to_parquet(f'data/Datasets/collct_pna_09_17/DFsWithSigs/{outfile}.parquet')
# Out:
# 2024-09-15 10:02:02,572 - pykrylov.util.config [MainThread  ] [WARNI]  Add MMS_V1 entry to config clusters; No action needed on users' side
# 2024-09-15 10:02:02,573 - pykrylov.util.config [MainThread  ] [WARNI]  Update MMS_V1 Server to https://krylov-mms.vip.ebay.com and ProxyServer to c2sproxy;No action needed on users' side
# loading configuration file /data/shpx/data/mmandelbrod/.cache/ellement/athena-mvp/Mistral-7B-Instruct-v02/1/config.json
# Model config MistralConfig {
#   "_name_or_path": "/data/shpx/data/mmandelbrod/.cache/ellement/athena-mvp/Mistral-7B-Instruct-v02/1",
#   "architectures": [
#     "MistralForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "head_dim": 128,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 32768,
#   "model_type": "mistral",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
# ...

# %% [markdown]
# # Dataset hag_pna_collct_09_24

# %% [markdown]
# ## Collectibles

# %%
collct_df = pd.read_parquet('data/Datasets/hag_pna_collct_09_24/RawExtracted/collct_us_09_27.parquet')

collct_df_amended_with_forbidden = post_extraction_amendments(collct_df, should_remove_forbidden_tokens=False, apply_html_to_plain = True)
collct_df_amended_with_forbidden
collct_df_amended_no_forbidden = post_extraction_amendments(collct_df, should_remove_forbidden_tokens=True, apply_html_to_plain = True)
collct_df_amended_no_forbidden
# Out:
#            item_id                                          item_desc  \
# 0     126643930817  PGRpdiBzdHlsZT0iIndpZHRoOiAxMDAlOyB0ZXh0LWFsaW...
# 1     144570721711  PHN0eWxlPmltZ3ttYXgtd2lkdGg6MTAwJX08L3N0eWxlPj...
# 2     145854441123  CgoKCTxtZXRhIGNoYXJzZXQ9InV0Zi04Ij4KCTxtZXRhIG...
# 3     145978761092  PHAgY2xhc3M9Ik1zb05vcm1hbCIgc3R5bGU9InRleHQtYW...
# 4     156274109142  PHN0eWxlIHR5cGU9J3RleHQvY3NzJz4KaHRtbCwgYm9keS...
# ...            ...                                                ...
# 9995  326176436617  PCEtLSBWZXJzaW9uOiBTaXhCaXQgQWdlbnQgNC4wLjI0Ny...
# 9996  353432532874  PGZvbnQgcndyPScxJyBzaXplPSc0JyBzdHlsZT0nZm9udC...
# 9997  363119549857  PGZvbnQgc2l6ZT0iNCI+PGZvbnQgc3R5bGU9ImJhY2tncm...
# 9998  371992756516  PFRBQkxFIENFTExTUEFDSU5HPSIyOCIgQ0VMTFBBRERJTk...
# 9999  387311205165  PGRpdiBzdHlsZT0iZm9udC1mYW1pbHk6IFRpbWVzOyI+PH...
#
#                                                   title SUBTITLE  \
# ...

# %%
collct_df_amended_with_forbidden['desc'].astype(str).str.contains('|'.join(forbidden_words), case=False).mean(),\
collct_df_amended_no_forbidden['desc_no_forbidden'].astype(str).str.contains('|'.join(forbidden_words), case=False).mean()
# Out:
# (0.9235, 0.0)

# %%
# !mkdir data/Datasets/hag_pna_collct_09_24/GenSigsData/JsonTemp
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
collct_df_amended_with_forbidden.to_csv('data/Datasets/hag_pna_collct_09_24/ExtractedAmended/collct_us_09_27_with_forbidden.csv')
collct_df_amended_no_forbidden.to_csv('data/Datasets/hag_pna_collct_09_24/ExtractedAmended/collct_us_09_27_no_forbidden.csv')

# %%
collct_df_amended_with_forbidden = pd.read_csv('data/Datasets/hag_pna_collct_09_24/ExtractedAmended/collct_us_09_27_with_forbidden.csv', index_col = 0)
collct_df_amended_no_forbidden = pd.read_csv('data/Datasets/hag_pna_collct_09_24/ExtractedAmended/collct_us_09_27_no_forbidden.csv', index_col = 0)

# %%
outfile_with_forbidden = 'collct_with_forbidden_mistral'
outfile_no_forbidden = 'collct_no_forbidden_mistral'
outpath_tmp_json = 'data/Datasets/hag_pna_collct_09_24/GenSigsData/JsonTemp'
outpath_final = 'data/Datasets/hag_pna_collct_09_24/GenSigsData'

# collct_df_with_sigs_with_forbidden = await generate_signals_per_item(collct_df_amended_with_forbidden, 
#                                                       cols_for_prompt=['title', 'aspects', 'desc'], 
#                                                       outfile=f'{outpath_tmp_json}/{outfile_with_forbidden}.jsonl',  model_name='mistral') 
# collct_df_with_sigs_with_forbidden.to_parquet(f'{outpath_final}/{outfile_with_forbidden}.parquet')


collct_df_with_sigs_no_forbidden = await generate_signals_per_item(collct_df_amended_no_forbidden, 
                                                      cols_for_prompt=['title_no_forbidden', 'aspects_no_forbidden', 'desc_no_forbidden'], 
                                                      outfile=f'{outpath_tmp_json}/{outfile_no_forbidden}.jsonl',  model_name='mistral') 
collct_df_with_sigs_no_forbidden.to_parquet(f'{outpath_final}/{outfile_no_forbidden}.parquet')
# Out:
# 2024-09-16 05:08:25,717 - pykrylov.util.config [MainThread  ] [WARNI]  Add MMS_V1 entry to config clusters; No action needed on users' side
# 2024-09-16 05:08:25,718 - pykrylov.util.config [MainThread  ] [WARNI]  Update MMS_V1 Server to https://krylov-mms.vip.ebay.com and ProxyServer to c2sproxy;No action needed on users' side
# loading configuration file /data/shpx/data/mmandelbrod/.cache/ellement/athena-mvp/Mistral-7B-Instruct-v02/1/config.json
# Model config MistralConfig {
#   "_name_or_path": "/data/shpx/data/mmandelbrod/.cache/ellement/athena-mvp/Mistral-7B-Instruct-v02/1",
#   "architectures": [
#     "MistralForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "head_dim": 128,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 32768,
#   "model_type": "mistral",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
# ...

# %% [markdown]
# ## P&A

# %%
pna_df = pd.read_parquet('data/Datasets/hag_pna_collct_09_24/RawExtracted/pna_us_09_27.parquet')
pna_df
# pna_df_amended_with_forbidden = post_extraction_amendments(pna_df, should_remove_forbidden_tokens=False, apply_html_to_plain = True)
# pna_df_amended_with_forbidden
pna_df_amended = post_extraction_amendments(pna_df, should_remove_forbidden_tokens=True, apply_html_to_plain = True)
pna_df_amended
# Out:
#            item_id                                          item_desc  \
# 0     116229424196  PG1ldGEgbmFtZT0ia2V5d29yZHMiIGNvbnRlbnQ9InVzZW...
# 1     126028451215  PGZvbnQgcndyPSIxIiBzdHlsZT0iIj48ZGl2IHN0eWxlPS...
# 2     134952985532  PCEtLSBEZXNjVGVtcGxhdGVJRDogRnJvbnQgQm9keSAoNj...
# 3     135211723255  PHN0eWxlPgogICAgQG1lZGlhIHNjcmVlbiBhbmQgKG1heC...
# 4     144432285379  PCEtLSBCRUdJTiBWSURFTyAtLT4KPGRpdiBjbGFzcz0iZn...
# ...            ...                                                ...
# 9981  394481992200  CiAgPCFET0NUWVBFIGh0bWw+CjxodG1sIGxhbmc9ImVuIj...
# 9982  395618655825  PG1ldGEgY2hhcnNldD0iVVRGLTgiPgo8bWV0YSBuYW1lPS...
# 9983  402382727509  CgkJCQkJICA8IURPQ1RZUEUgaHRtbD4KPGh0bWwgbGFuZz...
# 9984  405123346459  PCEtLXRvbmd0b29sLXJlbGF0ZWRDc3NTdGFydC0tPjxsaW...
# 9985  405191096532  PGh0bWw+Cgo8aGVhZD4KICAgIDxtZXRhIG5hbWU9InZpZX...
#
#                                                   title SUBTITLE  \
# ...

# %%
pna_df_amended.to_csv('data/Datasets/hag_pna_collct_09_24/ExtractedAmended/pna_us_09_27_amended.csv')

# %%
pna_df_amended_1 = pd.read_csv('data/Datasets/hag_pna_collct_09_24/ExtractedAmended/pna_us_09_27_amended.csv')
pna_df_amended_1
# Out:
#       Unnamed: 0       item_id  \
# 0              0  116229424196
# 1              1  126028451215
# 2              2  134952985532
# 3              3  135211723255
# 4              4  144432285379
# ...          ...           ...
# 9981        9981  394481992200
# 9982        9982  395618655825
# 9983        9983  402382727509
# 9984        9984  405123346459
# 9985        9985  405191096532
#
#                                               item_desc  \
# 0     PG1ldGEgbmFtZT0ia2V5d29yZHMiIGNvbnRlbnQ9InVzZW...
# 1     PGZvbnQgcndyPSIxIiBzdHlsZT0iIj48ZGl2IHN0eWxlPS...
# 2     PCEtLSBEZXNjVGVtcGxhdGVJRDogRnJvbnQgQm9keSAoNj...
# 3     PHN0eWxlPgogICAgQG1lZGlhIHNjcmVlbiBhbmQgKG1heC...
# 4     PCEtLSBCRUdJTiBWSURFTyAtLT4KPGRpdiBjbGFzcz0iZn...
# ...                                                 ...
# 9981  CiAgPCFET0NUWVBFIGh0bWw+CjxodG1sIGxhbmc9ImVuIj...
# 9982  PG1ldGEgY2hhcnNldD0iVVRGLTgiPgo8bWV0YSBuYW1lPS...
# 9983  CgkJCQkJICA8IURPQ1RZUEUgaHRtbD4KPGh0bWwgbGFuZz...
# ...

# %%
pna_df_amended_with_forbidden['desc'].astype(str).str.contains('|'.join(forbidden_words), case=False).mean(),\
pna_df_amended_no_forbidden['desc_no_forbidden'].astype(str).str.contains('|'.join(forbidden_words), case=False).mean()

# %%
pna_df_amended_with_forbidden.to_csv('data/Datasets/hag_pna_collct_09_24/ExtractedAmended/pna_us_09_27_with_forbidden.csv')
pna_df_amended_no_forbidden.to_csv('data/Datasets/hag_pna_collct_09_24/ExtractedAmended/pna_us_09_27_no_forbidden.csv')

# %%
# pna_df_amended_with_forbidden = pd.read_csv('data/Datasets/hag_pna_collct_09_24/ExtractedAmended/pna_us_09_27_with_forbidden.csv', index_col = 0)
# pna_df_amended_no_forbidden = pd.read_csv('data/Datasets/hag_pna_collct_09_24/ExtractedAmended/pna_us_09_27_no_forbidden.csv', index_col = 0)

# %%
outfile_with_forbidden = 'pna_with_forbidden_mistral'
outfile_no_forbidden = 'pna_no_forbidden_mistral'
outpath_tmp_json = 'data/Datasets/hag_pna_collct_09_24/GenSigsData/JsonTemp'
outpath_final = 'data/Datasets/hag_pna_collct_09_24/GenSigsData'

pna_df_with_sigs_with_forbidden = await generate_signals_per_item(pna_df_amended_with_forbidden, 
                                                      cols_for_prompt=['title', 'aspects', 'desc'], 
                                                      outfile=f'{outpath_tmp_json}/{outfile_with_forbidden}.jsonl',  model_name='mistral') 
pna_df_with_sigs_with_forbidden.to_parquet(f'{outpath_final}/{outfile_with_forbidden}.parquet')


pna_df_with_sigs_no_forbidden = await generate_signals_per_item(pna_df_amended_no_forbidden, 
                                                      cols_for_prompt=['title_no_forbidden', 'aspects_no_forbidden', 'desc_no_forbidden'], 
                                                      outfile=f'{outpath_tmp_json}/{outfile_no_forbidden}.jsonl',  model_name='mistral') 
pna_df_with_sigs_no_forbidden.to_parquet(f'{outpath_final}/{outfile_no_forbidden}.parquet')

# %%
df_amended = pd.read_csv('data/Datasets/hag_pna_collct_09_24/ExtractedAmended/pna_us_09_27_amended.csv', index_col = 0)
df_amended
# Out:
#            item_id                                          item_desc  \
# 0     116229424196  PG1ldGEgbmFtZT0ia2V5d29yZHMiIGNvbnRlbnQ9InVzZW...
# 1     126028451215  PGZvbnQgcndyPSIxIiBzdHlsZT0iIj48ZGl2IHN0eWxlPS...
# 2     134952985532  PCEtLSBEZXNjVGVtcGxhdGVJRDogRnJvbnQgQm9keSAoNj...
# 3     135211723255  PHN0eWxlPgogICAgQG1lZGlhIHNjcmVlbiBhbmQgKG1heC...
# 4     144432285379  PCEtLSBCRUdJTiBWSURFTyAtLT4KPGRpdiBjbGFzcz0iZn...
# ...            ...                                                ...
# 9981  394481992200  CiAgPCFET0NUWVBFIGh0bWw+CjxodG1sIGxhbmc9ImVuIj...
# 9982  395618655825  PG1ldGEgY2hhcnNldD0iVVRGLTgiPgo8bWV0YSBuYW1lPS...
# 9983  402382727509  CgkJCQkJICA8IURPQ1RZUEUgaHRtbD4KPGh0bWwgbGFuZz...
# 9984  405123346459  PCEtLXRvbmd0b29sLXJlbGF0ZWRDc3NTdGFydC0tPjxsaW...
# 9985  405191096532  PGh0bWw+Cgo8aGVhZD4KICAgIDxtZXRhIG5hbWU9InZpZX...
#
#                                                   title SUBTITLE  \
# ...

# %%
df_gen_with_forbidden = pd.read_json('data/Datasets/hag_pna_collct_09_24/GenSigsData/JsonTemp/pna_no_forbidden_mistral.jsonl', lines=True)
df_gen_with_forbidden
# Out:
#                                                       0
# 0     {"characteristic": "OEM handle, 'type': 'handl...
# 1     {"characteristic": "New and Unused", "explanat...
# 2     {\n"characteristic": "Fits 95-96 Ford E150 Van...
# 3     {\n"characteristic": "Fits Harley Touring Mode...
# 4     {"characteristic": "10,000 hours bulb life",\n...
# ...                                                 ...
# 9981  {\n"characteristic": "New Brand: Standard Moto...
# 9982  {"characteristic": "Durable, anti-scratch",\n ...
# 9983  {"characteristic": "New DuraKlear Plus blade",...
# 9984  {"characteristic": "Durable aluminum housing",...
# 9985  {"characteristic": "New, Chrome Finish", "expl...
#
# [9986 rows x 1 columns]

# %%
df_gen_with_forbidden.iloc[0,0]
# Out:
# '{"characteristic": "OEM handle, \'type\': \'handle\'",\n "explanation": "This product is an original equipment manufacturer (OEM) part, meaning it is a genuine Mercedes-Benz part. The inclusion of the handle type makes it clear this is for the recline function of the seat backrest. This information can provide buyers peace of mind knowing they are getting an authentic Mercedes-Benz part that is specifically designed to fit their vehicle and function correctly."}'

# %%
df_amended[', len(df_gen_with_forbidden)
# Out:
# (9986, 9986)

# %%
df = pd.read_parquet('data/Datasets/hag_pna_collct_09_24/GenSigsData/pna_with_forbidden_mistral.parquet')
df
# Out:
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = pd.read_parquet('data/Datasets/hag_pna_collct_09_24/GenSigsData/pna_with_forbidden_mistral.parquet')
#       2 df
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     664     use_nullable_dtypes = False
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
#     669     columns=columns,
#     670     filters=filters,
#     671     storage_options=storage_options,
#     672     use_nullable_dtypes=use_nullable_dtypes,
#     673     dtype_backend=dtype_backend,
#     674     filesystem=filesystem,
#     675     **kwargs,
#     676 )
#
# ...

# %%
# !ls data/Datasets/hag_pna_collct_09_24/ExtractedAmended/
# Out:
# collct_us_09_27_no_forbidden.csv    hag_us_09_27_no_forbidden.csv
# collct_us_09_27_with_forbidden.csv  pna_us_09_27_amended.csv

# %% [markdown]
# ## H&G

# %%
hag_df = pd.read_parquet('data/Datasets/hag_pna_collct_09_24/RawExtracted/hag_us_09_27.parquet')
hag_df_amended_no_forbidden = post_extraction_amendments(hag_df, should_remove_forbidden_tokens=True, apply_html_to_plain = True)
hag_df_amended_no_forbidden
# Out:
#            item_id                                          item_desc  \
# 0     115716360798  U2Ftc3VuZyBXRjM1MEFOUC9YQUEtMDMgV2FzaGVyIFdhdG...
# 1     116118610650  PG1ldGEgY29udGVudD0id2lkdGg9ZGV2aWNlLXdpZHRoLC...
# 2     125737560178  VGhpcyBpcyBhIE5ldyBTdGlobCBDaGFpbiBPaWxvbWF0aW...
# 3     125949363700  PG1ldGEgY29udGVudD0id2lkdGg9ZGV2aWNlLXdpZHRoLC...
# 4     126299016733  PGRpdiBjbGFzcz0iZHhtLWViYXktcmVsYXRlZC1tYXJrZX...
# ...            ...                                                ...
# 9995  375143663324  PGRpdiBjbGFzcz0ibGFiZWwtY29udGVudCIgc3R5bGU9Im...
# 9996  375395567062  PGh0bWwgbGFuZz0iZW4iPgo8aGVhZD4KCTx0aXRsZT48L3...
# 9997  386227820982  PHA+PGI+VGhpcyBBSVJDQVJFIDEwNDMgU3VwZXIgV2ljay...
# 9998  404402096749  PGRpdj48dGFibGUgYWxpZ249ImNlbnRlciIgc3R5bGU9Im...
# 9999  405190756854  RWxldmF0ZSB5b3VyIHNwYWNlIHdpdGggb3VyIHRvcC10aW...
#
#                                                   title SUBTITLE  \
# ...

# %%
hag_df_amended_no_forbidden
# Out:
#            item_id                                          item_desc  \
# 0     115716360798  U2Ftc3VuZyBXRjM1MEFOUC9YQUEtMDMgV2FzaGVyIFdhdG...
# 1     116118610650  PG1ldGEgY29udGVudD0id2lkdGg9ZGV2aWNlLXdpZHRoLC...
# 2     125737560178  VGhpcyBpcyBhIE5ldyBTdGlobCBDaGFpbiBPaWxvbWF0aW...
# 3     125949363700  PG1ldGEgY29udGVudD0id2lkdGg9ZGV2aWNlLXdpZHRoLC...
# 4     126299016733  PGRpdiBjbGFzcz0iZHhtLWViYXktcmVsYXRlZC1tYXJrZX...
# ...            ...                                                ...
# 9995  375143663324  PGRpdiBjbGFzcz0ibGFiZWwtY29udGVudCIgc3R5bGU9Im...
# 9996  375395567062  PGh0bWwgbGFuZz0iZW4iPgo8aGVhZD4KCTx0aXRsZT48L3...
# 9997  386227820982  PHA+PGI+VGhpcyBBSVJDQVJFIDEwNDMgU3VwZXIgV2ljay...
# 9998  404402096749  PGRpdj48dGFibGUgYWxpZ249ImNlbnRlciIgc3R5bGU9Im...
# 9999  405190756854  RWxldmF0ZSB5b3VyIHNwYWNlIHdpdGggb3VyIHRvcC10aW...
#
#                                                   title SUBTITLE  \
# ...

# %%
hag_df_amended_no_forbidden['desc'].astype(str).str.contains('|'.join(forbidden_words), case=False).mean(),\
hag_df_amended_no_forbidden['desc_no_forbidden'].astype(str).str.contains('|'.join(forbidden_words), case=False).mean()
# Out:
# (0.9405, 0.0)

# %%
hag_df_amended_no_forbidden.to_csv('data/Datasets/hag_pna_collct_09_24/ExtractedAmended/hag_us_09_27_no_forbidden.csv')

# %%
hag_df_amended_no_forbidden = pd.read_csv('data/Datasets/hag_pna_collct_09_24/ExtractedAmended/hag_us_09_27_no_forbidden.csv', index_col = 0)
hag_df_amended_no_forbidden
# Out:
#            item_id                                          item_desc  \
# 0     115716360798  U2Ftc3VuZyBXRjM1MEFOUC9YQUEtMDMgV2FzaGVyIFdhdG...
# 1     116118610650  PG1ldGEgY29udGVudD0id2lkdGg9ZGV2aWNlLXdpZHRoLC...
# 2     125737560178  VGhpcyBpcyBhIE5ldyBTdGlobCBDaGFpbiBPaWxvbWF0aW...
# 3     125949363700  PG1ldGEgY29udGVudD0id2lkdGg9ZGV2aWNlLXdpZHRoLC...
# 4     126299016733  PGRpdiBjbGFzcz0iZHhtLWViYXktcmVsYXRlZC1tYXJrZX...
# ...            ...                                                ...
# 9995  375143663324  PGRpdiBjbGFzcz0ibGFiZWwtY29udGVudCIgc3R5bGU9Im...
# 9996  375395567062  PGh0bWwgbGFuZz0iZW4iPgo8aGVhZD4KCTx0aXRsZT48L3...
# 9997  386227820982  PHA+PGI+VGhpcyBBSVJDQVJFIDEwNDMgU3VwZXIgV2ljay...
# 9998  404402096749  PGRpdj48dGFibGUgYWxpZ249ImNlbnRlciIgc3R5bGU9Im...
# 9999  405190756854  RWxldmF0ZSB5b3VyIHNwYWNlIHdpdGggb3VyIHRvcC10aW...
#
#                                                   title SUBTITLE  \
# ...

# %%
# outfile_with_forbidden = 'hag_with_forbidden_mistral'
outfile_no_forbidden = 'hag_no_forbidden_mistral_cont'
outpath_tmp_json = 'data/Datasets/hag_pna_collct_09_24/GenSigsData/JsonTemp'
outpath_final = 'data/Datasets/hag_pna_collct_09_24/GenSigsData'

# hag_df_with_sigs_with_forbidden = await generate_signals_per_item(hag_df_amended_no_forbidden, 
#                                                       cols_for_prompt=['title', 'aspects', 'desc'], 
#                                                       outfile=f'{outpath_tmp_json}/{outfile_with_forbidden}.jsonl',  model_name='mistral') 
# hag_df_with_sigs_with_forbidden.to_parquet(f'{outpath_final}/{outfile_with_forbidden}.parquet')


hag_df_with_sigs_no_forbidden = await generate_signals_per_item(hag_df_amended_no_forbidden[2373:], 
                                                      cols_for_prompt=['title_no_forbidden', 'aspects_no_forbidden', 'desc_no_forbidden'], 
                                                      outfile=f'{outpath_tmp_json}/{outfile_no_forbidden}.jsonl',  model_name='mistral') 
hag_df_with_sigs_no_forbidden.to_parquet(f'{outpath_final}/{outfile_no_forbidden}.parquet')
# Out:
# 2024-09-17 14:30:49,848 - pykrylov.util.config [MainThread  ] [WARNI]  Add MMS_V1 entry to config clusters; No action needed on users' side
# 2024-09-17 14:30:49,849 - pykrylov.util.config [MainThread  ] [WARNI]  Update MMS_V1 Server to https://krylov-mms.vip.ebay.com and ProxyServer to c2sproxy;No action needed on users' side
# loading configuration file /data/shpx/data/mmandelbrod/.cache/ellement/athena-mvp/Mistral-7B-Instruct-v02/1/config.json
# Model config MistralConfig {
#   "_name_or_path": "/data/shpx/data/mmandelbrod/.cache/ellement/athena-mvp/Mistral-7B-Instruct-v02/1",
#   "architectures": [
#     "MistralForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "head_dim": 128,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 32768,
#   "model_type": "mistral",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
# ...

# %%
hag_df_with_sigs_no_forbidden
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 hag_df_with_sigs_no_forbidden
#
# NameError: name 'hag_df_with_sigs_no_forbidden' is not defined

# %%
df = pd.read_parquet('data/Datasets/hag_pna_collct_09_24/GenSigsData/hag_with_forbidden_mistral.parquet')
df
# Out:
#            item_id                                          item_desc  \
# 0     115716360798  U2Ftc3VuZyBXRjM1MEFOUC9YQUEtMDMgV2FzaGVyIFdhdG...
# 1     116118610650  PG1ldGEgY29udGVudD0id2lkdGg9ZGV2aWNlLXdpZHRoLC...
# 2     125737560178  VGhpcyBpcyBhIE5ldyBTdGlobCBDaGFpbiBPaWxvbWF0aW...
# 3     125949363700  PG1ldGEgY29udGVudD0id2lkdGg9ZGV2aWNlLXdpZHRoLC...
# 4     126299016733  PGRpdiBjbGFzcz0iZHhtLWViYXktcmVsYXRlZC1tYXJrZX...
# ...            ...                                                ...
# 9995  375143663324  PGRpdiBjbGFzcz0ibGFiZWwtY29udGVudCIgc3R5bGU9Im...
# 9996  375395567062  PGh0bWwgbGFuZz0iZW4iPgo8aGVhZD4KCTx0aXRsZT48L3...
# 9997  386227820982  PHA+PGI+VGhpcyBBSVJDQVJFIDEwNDMgU3VwZXIgV2ljay...
# 9998  404402096749  PGRpdj48dGFibGUgYWxpZ249ImNlbnRlciIgc3R5bGU9Im...
# 9999  405190756854  RWxldmF0ZSB5b3VyIHNwYWNlIHdpdGggb3VyIHRvcC10aW...
#
#                                                   title SUBTITLE  \
# ...

# %% [markdown]
# ## Merge dfs

# %%
df = pd.read_parquet('data/Datasets/hag_pna_collct_09_24/GenSigsData/hag/hag_with_forbidden_mistral.parquet')
df
# Out:
#            item_id                                          item_desc  \
# 0     115716360798  U2Ftc3VuZyBXRjM1MEFOUC9YQUEtMDMgV2FzaGVyIFdhdG...
# 1     116118610650  PG1ldGEgY29udGVudD0id2lkdGg9ZGV2aWNlLXdpZHRoLC...
# 2     125737560178  VGhpcyBpcyBhIE5ldyBTdGlobCBDaGFpbiBPaWxvbWF0aW...
# 3     125949363700  PG1ldGEgY29udGVudD0id2lkdGg9ZGV2aWNlLXdpZHRoLC...
# 4     126299016733  PGRpdiBjbGFzcz0iZHhtLWViYXktcmVsYXRlZC1tYXJrZX...
# ...            ...                                                ...
# 9995  375143663324  PGRpdiBjbGFzcz0ibGFiZWwtY29udGVudCIgc3R5bGU9Im...
# 9996  375395567062  PGh0bWwgbGFuZz0iZW4iPgo8aGVhZD4KCTx0aXRsZT48L3...
# 9997  386227820982  PHA+PGI+VGhpcyBBSVJDQVJFIDEwNDMgU3VwZXIgV2ljay...
# 9998  404402096749  PGRpdj48dGFibGUgYWxpZ249ImNlbnRlciIgc3R5bGU9Im...
# 9999  405190756854  RWxldmF0ZSB5b3VyIHNwYWNlIHdpdGggb3VyIHRvcC10aW...
#
#                                                   title SUBTITLE  \
# ...

# %%
df[df['gen_sig_mistral'] == '']['gen_text_mistral'].unique()
# Out:
# array([None], dtype=object)
