# %% [markdown]
# # Setup

# %%
base_path_kry = '/home/mmandelbrod/repositories/'
base_path_mac = '/Users/mmandelbrod/workspace/'
import sys
import os

tmp = !hostname
if tmp[0].startswith('krylov'):
    on_kry = True
else: 
    on_kry = False
    
base_path = base_path_kry if on_kry else base_path_mac

print(base_path)

sys.path.append(os.path.join(base_path, 'signals/'))
# sys.path.append(os.path.join(base_path, 'signals/src'))
sys.path.append(os.path.join(base_path, 'generative-signals/'))
sys.path.append(os.path.join(base_path, 'generative-signals/src'))
sys.path.append(os.path.join(base_path, 'signals/workflows/pipelines/'))
sys.path.append(os.path.join(base_path, 'signals/workflows/global_utils/'))
sys.path.append(os.path.join(base_path, 'signals/workflows'))
sys.path.append(os.path.join(base_path, 'matans_sandbox/utils'))

sys.path.append(base_path)
sys.path.append(os.path.join(base_path, 'signals/'))
# sys.path.append(os.path.join(base_path, 'signals/src'))
sys.path.append(os.path.join(base_path, 'generative-signals/'))
sys.path.append(os.path.join(base_path, 'generative-signals/src'))
sys.path.append(os.path.join(base_path, 'generative-signals/dev/generation'))
sys.path.append(os.path.join(base_path, 'signals/workflows/pipelines/'))
sys.path.append(os.path.join(base_path, 'signals/workflows/global_utils/'))
sys.path.append(os.path.join(base_path, 'signals/workflows'))
sys.path.append(os.path.join(base_path, 'matans_sandbox/utils'))
sys.path.append(os.path.join(base_path, 'gpt_call_async'))

os.chdir(os.path.join(base_path,'generative-signals'))
print(f"curr dir: {os.getcwd()}")
# Out:
# /home/mmandelbrod/repositories/
# curr dir: /home/mmandelbrod/repositories/generative-signals

# %%
import pyspark.sql.functions as F
import pandas as pd
import time
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pyspark.sql.functions as F
#       2 import pandas as pd
#       3 import time
#
# ModuleNotFoundError: No module named 'pyspark'

# %%
import warnings
warnings.filterwarnings("ignore")
import os
import sys
import base64
from bs4 import BeautifulSoup
import re
from pyspark.sql.functions import broadcast
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 8
#       6 from bs4 import BeautifulSoup
#       7 import re
# ----> 8 from pyspark.sql.functions import broadcast
#
# ModuleNotFoundError: No module named 'pyspark'

# %%
from data_extraction.extraction_funcs import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from data_extraction.extraction_funcs import *
#
# File ~/repositories/generative-signals/src/data_extraction/extraction_funcs.py:2
#       1 import pandas as pd
# ----> 2 from pyspark.sql import SparkSession
#       3 from pyspark.sql.types import MapType, StringType
#       4 import pyspark.sql.functions as F
#
# ModuleNotFoundError: No module named 'pyspark'

# %%
import data_extraction.extraction_funcs
from data_extraction.extraction_funcs import *

# %%
bxkrylov.spark_notebook??
# Out:
# Object `bxkrylov.spark_notebook` not found.

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import os
import sys
import base64
from bs4 import BeautifulSoup
import re
import json
import os
from datetime import datetime
from functools import reduce
from typing import List
import gzip
import numpy as np
from generation.sigs_gen import *
from data_extraction.extraction_funcs import *
from generation.generators import gpt_generator, mistral_generator
from evaluation.metrics import *
os.getcwd()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 16
#      14 import gzip
#      15 import numpy as np
# ---> 16 from generation.sigs_gen import *
#      17 from data_extraction.extraction_funcs import *
#      18 from generation.generators import gpt_generator, mistral_generator
#
# File ~/repositories/generative-signals/src/generation/sigs_gen.py:22
#      18 # from langchain import PromptTemplate
#      19 # from langchain.chains import LLMChain
#      21 from generation.generators.gpt_generator import SignalsGeneratorGPT
# ---> 22 from generation.generators.mistral_generator import SignalsGeneratorMistral
#      23 from data_extraction.extraction_funcs import filter_aspects
#      24 from data_extraction.extraction_funcs import forbidden_words
#
# File ~/repositories/generative-signals/src/generation/generators/mistral_generator.py:5
# ...

# %%
import json
import os
from datetime import datetime
from functools import reduce
from typing import List

import bxkrylov
# import bx_signals.etl.signals_fetcher as fetcher
from pyspark.sql.functions import array, col, expr, lower, when, row_number, lit, first, get_json_object, from_json, explode, split, count, collect_list, concat_ws, array_distinct, map_values, aggregate, size, regexp_replace, isnull, filter
from pyspark.sql.types import StructType, StructField, StringType, ArrayType, MapType, IntegerType, LongType
from pyspark.sql.functions import array_intersect, array_contains, array_except, coalesce, map_keys
from pyspark.sql import DataFrame

directory = "./signals_sanity_reports"
if not os.path.exists(directory):
    os.makedirs(directory)
    
min_execs = 400
max_execs = 1000


# .config("spark.shuffle.io.maxRetries", "10") \
#     .config("spark.shuffle.io.retryWait", "5s") \
#     .config("spark.reducer.maxSizeInFlight", "96m") \
#     .config("spark.speculation", "true") \
#     .config("spark.speculation.quantile", "0.75") \
#     .config("spark.speculation.multiplier", "1.5") \


bxkrylov.spark_notebook(globals(),
                        spark_dynamicAllocation_minExecutors=min_execs,
                        spark_executor_instances=min_execs,
                        spark_dynamicAllocation_initialExecutors=min_execs,
                        spark_dynamicAllocation_maxExecutors=max_execs,
                        spark_executor_memory="10g",
                        spark_driver_maxResultSize="26g",
                        spark_executor_memoryOverhead="26g",
                        spark_driver_memory="80g",
                        spark_kryoserializer_buffer_max="1500m",
                        spark_executor_cores="5", 
                        spark_shuffle_io_maxRetries="10", 
                        spark_shuffle_io_retryWait="5s",
                        spark_reducer_maxSizeInFlight="96m",
                        spark_network_timeout="800s",
                        spark_executor_heartbeatInterval="60s"                        
                        )

directory = "./signals_sanity_reports"
if not os.path.exists(directory):
    os.makedirs(directory)
    
# !python3 -V
spark.sparkContext.setLogLevel("OFF")
spark
# Out:
# bxkrylov - using spark config:  {
#     "spark.driver.host": "10.130.66.22",
#     "spark.rdd.compress": true,
#     "spark.network.timeout": "800s",
#     "spark.executor.heartbeatInterval": "60s",
#     "spark.sql.broadcastTimeout": "12000s",
#     "spark.yarn.queue": "hdlq-exprce-default",
#     "spark.executor.extraJavaOptions": "-XX:MaxMetaspaceSize=512m -XX:ParallelGCThreads=3",
#     "spark.driver.extraJavaOptions": "-XX:MaxMetaspaceSize=512m -XX:ParallelGCThreads=3",
#     "spark.speculation": true,
#     "spark.executor.cores": "5",
#     "spark.driver.memory": "80g",
#     "spark.executor.memory": "10g",
#     "spark.driver.maxResultSize": "26g",
#     "spark.dynamicAllocation.maxExecutors": 1000,
#     "spark.dynamicAllocation.minExecutors": 400,
#     "spark.executor.instances": 400,
#     "spark.dynamicAllocation.initialExecutors": 400,
#     "spark.executor.memoryOverhead": "26g",
#     "spark.kryoserializer.buffer.max": "1500m",
# ...

# %%
spark
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 spark
#
# NameError: name 'spark' is not defined

# %%
sys.path
# Out:
# ['/home/mmandelbrod/repositories/generative-signals/notebooks/data_extraction',
#  '/tmp/spark-7d8c3c9a-2ec7-4985-b10c-1683515e2813/userFiles-676613bd-b8ab-4189-84eb-b498e54475c2',
#  '/opt/clients/pykrylov/3.10/latest/install',
#  '/home/mmandelbrod/repositories/generative-signals/notebooks/data_extraction',
#  '/opt/conda/lib/python310.zip',
#  '/opt/conda/lib/python3.10',
#  '/opt/conda/lib/python3.10/lib-dynload',
#  '',
#  '/home/mmandelbrod/.local/lib/python3.10/site-packages',
#  '/opt/conda/lib/python3.10/site-packages',
#  '/opt/clients/propeller/3.10/latest/install',
#  '/home/mmandelbrod/repositories/signals/',
#  '/home/mmandelbrod/repositories/generative-signals/',
#  '/home/mmandelbrod/repositories/generative-signals/src',
#  '/home/mmandelbrod/repositories/signals/workflows/pipelines/',
#  '/home/mmandelbrod/repositories/signals/workflows/global_utils/',
#  '/home/mmandelbrod/repositories/signals/workflows',
#  '/home/mmandelbrod/repositories/matans_sandbox/utils',
# ...

# %% [markdown]
# ## importlib

# %%
import importlib
def refresh_module(module_name):
    try:
        module = importlib.import_module(module_name)
        importlib.reload(module)
        module = importlib.import_module(module_name)
        globals().update(module.__dict__)
    except ImportError as e:
        print(f"Error importing module {module_name}: {e}")
        return None

# %%
refresh_module('evaluation.metrics')

# %%
import importlib

import data_extraction.extraction_funcs
importlib.reload(data_extraction.extraction_funcs)
import data_extraction.extraction_funcs
from data_extraction.extraction_funcs import *

# import dataset_utils
# importlib.reload(dataset_utils)
# import dataset_utils
# from dataset_utils import *

# # import xgb_ranker_classifier_pipeline
# # importlib.reload(xgb_ranker_classifier_pipeline)
# # from xgb_ranker_classifier_pipeline import *

# import src.metrics.auuc_funcs
# importlib.reload(src.metrics.auuc_funcs)
# import src.metrics.auuc_funcs
# from src.metrics.auuc_funcs import *

# import pipelines.xgb_predict_signal_pipeline
# importlib.reload(pipelines.xgb_predict_signal_pipeline)
# import pipelines.xgb_predict_signal_pipeline
# from pipelines.xgb_predict_signal_pipeline import *



# import src.metrics.xgb_metrics_funcs
# importlib.reload(src.metrics.xgb_metrics_funcs)
# import src.metrics.xgb_metrics_funcs
# from src.metrics.auuc_funcs import *


# # import signals_pipeline_base
# # importlib.reload(signals_pipeline_base)
# #
# import pipelines.causalml_decision_tree_pipeline
# importlib.reload(pipelines.causalml_decision_tree_pipeline)
# import pipelines.causalml_decision_tree_pipeline
# from pipelines.causalml_decision_tree_pipeline import *

# # import config
# # importlib.reload(config)
# # from config import *

# import causal.causalml_funcs
# importlib.reload(causal.causalml_funcs)
# import causal.causalml_funcs
# from causal.causalml_funcs import *

# import pipeline_objects
# importlib.reload(pipeline_objects)
# from pipeline_objects import *
# #%%

# %% [markdown]
# # Dataset hag_pna_collct_09_24

# %% [markdown]
# ## Collectibles

# %% [markdown]
# Percentage and distribution of forbidden words in signals without filtering

# %%
k_tokens = 50

# %% [markdown]
# ### GPT

# %% [markdown]
# #### Frequency of words in the signals column

# %%
collct_gpt_with_forbidden = pd.read_parquet('data/Datasets/hag_pna_collct_09_24/GenSigsData/collectibles/collct_with_forbidden_gpt.parquet')
collct_gpt_no_forbidden = pd.read_parquet('data/Datasets/hag_pna_collct_09_24/GenSigsData/collectibles/collct_no_forbidden_gpt.parquet')

# %%
dists_with_forbidden = calc_words_frequency(collct_gpt_with_forbidden, 'gen_sig_gpt', density_as_perc=True)[:k_tokens][['Word', 'Density(%)']]
dists_with_forbidden
# Out:
#              Word  Density(%)
# 34           mint        4.31
# 5        original        3.84
# 57           near        3.46
# 58             or        3.10
# 59         better        2.99
# 76        vintage        2.26
# 36      condition        2.23
# 214          card        1.55
# 35      excellent        1.14
# 93       licensed        1.04
# 26        quality        1.01
# 122             1        0.73
# 25           high        0.67
# 70           rare        0.65
# 188           and        0.64
# 129     authentic        0.61
# 115           100        0.60
# 171       reprint        0.55
# 94   reproduction        0.54
# 14             in        0.51
# 3              of        0.49
# 128         scale        0.47
# 218         photo        0.45
# 192      shipping        0.43
# 101           new        0.43
# 501        signed        0.42
# 199          free        0.41
# 370         print        0.40
# 131         brand        0.39
# 322          hand        0.38
# ...

# %%
dists_no_forbidden = calc_words_frequency(collct_gpt_no_forbidden, 'gen_sig_gpt', density_as_perc=True)[:k_tokens][['Word', 'Density(%)']]
dists_no_forbidden
# Out:
#              Word  Density(%)
# 10          topps        1.69
# 118          card        1.37
# 31             of        1.18
# 7              in        1.08
# 100             1        1.06
# 145         scale        0.77
# 84          brand        0.75
# 54            set        0.74
# 93         united        0.73
# 94         states        0.69
# 27              5        0.68
# 95    manufacture        0.68
# 347            nm        0.66
# 15       material        0.60
# 19           mint        0.59
# 115   autographed        0.59
# 217      baseball        0.57
# 387            mt        0.56
# 25          prizm        0.53
# 267  manufactured        0.50
# 453      parallel        0.49
# 246        panini        0.48
# 154           and        0.48
# 96       handmade        0.46
# 77         silver        0.43
# 110          year        0.41
# 392        disney        0.40
# 346         print        0.40
# 17             10        0.40
# 102          2021        0.39
# ...

# %% [markdown]
# ### Mistral

# %%
sigs_collct_with_forbidden_mistral = pd.read_parquet('data/Datasets/hag_pna_collct_09_24/GenSigsData/collct_with_forbidden_mistral.parquet')
sigs_collct_with_forbidden_mistral
sigs_collct_no_forbidden_mistral = pd.read_parquet('data/Datasets/hag_pna_collct_09_24/GenSigsData/collct_no_forbidden_mistral.parquet')
sigs_collct_no_forbidden_mistral
# Out:
#            item_id                                          item_desc  \
# 0     126643930817  PGRpdiBzdHlsZT0iIndpZHRoOiAxMDAlOyB0ZXh0LWFsaW...
# 1     144570721711  PHN0eWxlPmltZ3ttYXgtd2lkdGg6MTAwJX08L3N0eWxlPj...
# 2     145854441123  CgoKCTxtZXRhIGNoYXJzZXQ9InV0Zi04Ij4KCTxtZXRhIG...
# 3     145978761092  PHAgY2xhc3M9Ik1zb05vcm1hbCIgc3R5bGU9InRleHQtYW...
# 4     156274109142  PHN0eWxlIHR5cGU9J3RleHQvY3NzJz4KaHRtbCwgYm9keS...
# ...            ...                                                ...
# 9995  326176436617  PCEtLSBWZXJzaW9uOiBTaXhCaXQgQWdlbnQgNC4wLjI0Ny...
# 9996  353432532874  PGZvbnQgcndyPScxJyBzaXplPSc0JyBzdHlsZT0nZm9udC...
# 9997  363119549857  PGZvbnQgc2l6ZT0iNCI+PGZvbnQgc3R5bGU9ImJhY2tncm...
# 9998  371992756516  PFRBQkxFIENFTExTUEFDSU5HPSIyOCIgQ0VMTFBBRERJTk...
# 9999  387311205165  PGRpdiBzdHlsZT0iZm9udC1mYW1pbHk6IFRpbWVzOyI+PH...
#
#                                                   title SUBTITLE  \
# ...

# %%
sigs_collct_with_forbidden_mistral['gen_sig_mistral'].astype(str).str.contains('|'.join(forbidden_words), case=False).mean()
# Out:
# 0.5688

# %%
sigs_collct_with_forbidden_mistral['gen_sig_mistral']
# Out:
# 0                                    Japanese Manufacture
# 1                               Vintage Mlb Baseball Card
# 2                                       Mint Original Gum
# 3
# 4                                        Glow In The Dark
#                               ...
# 9995                                   Unopened Envelopes
# 9996                                First Day Covers Sets
# 9997                         Original Print Advertisement
# 9998                                  Original Lobby Card
# 9999    Baseball, Autographs, Major League Baseball (Mlb)
# Name: gen_sig_mistral, Length: 10000, dtype: object

# %%
[s for s in sigs_collct_with_forbidden_mistral['gen_sig_mistral']]
# Out:
# ['Japanese Manufacture',
#  'Vintage Mlb Baseball Card',
#  'Mint Original Gum',
#  '',
#  'Glow In The Dark',
#  'Three Unique Dolls',
#  'Autograph Authentication By Jsa',
#  'Handblown Glass, Italy, 1960S',
#  'High Quality Cards',
#  'Vintage Pieces From 1962',
#  'Perfect 10 Psa Grade',
#  'Victorian Art',
#  'Rookie Daniel Oturu',
#  'Nick Cardy Cover Art',
#  'Unique Finds',
#  'Rookie Cards Included',
#  'Soft & Fluffy',
#  '2005 Manufacture',
#  'Ice Hockey Card',
#  'Nm-Mt Condition',
#  'Autographed By Kurt Ainsworth',
#  'Gold Trim, Porcelain Material',
#  'Blown Glass, Glitter',
#  '1994 New York Knicks',
#  'Vintage, Made In The Usa',
#  'Excellent Condition',
#  'Original Holy Bear Series',
#  'All Original',
#  'Vintage Plastic Tokens',
#  'Eight Cards Included',
#  'German, Bavaria Origin',
#  'Mirror Red Finish',
#  'Classic Brand, 1992 Series',
#  'Limited Edition',
#  'Original, Licensed Reproduction',
#  'Silver Age, Freebie Fun Packs',
# ...

# %%
k_tokens = 30

# %% [markdown]
# #### Frequency of words in the signals column

# %%
# dists_with_forbidden = calc_words_frequency(sigs_collct_with_forbidden_mistral, 'gen_sig_mistral', density_as_perc=True)[:k_tokens][['Word', 'Density(%)']]
# dists_with_forbidden

dists_no_forbidden = calc_words_frequency(sigs_collct_no_forbidden_mistral, 'gen_sig_mistral', density_as_perc=True)[:k_tokens][['Word', 'Density(%)']]
dists_no_forbidden
# Out:
#             Word  Density(%)
# 7         league        2.43
# 9            mlb        2.16
# 8       baseball        2.16
# 6          major        1.99
# 62        player        1.55
# 175            1        0.98
# 40          mint        0.88
# 1             of        0.82
# 177        scale        0.78
# 114        theme        0.77
# 292          nfl        0.76
# 160    condition        0.73
# 235         card        0.72
# 80         brand        0.69
# 56     franchise        0.62
# 43        rookie        0.62
# 228     football        0.61
# 74           nba        0.59
# 95        origin        0.56
# 155     japanese        0.54
# 167       graded        0.53
# 29            in        0.51
# 63   autographed        0.50
# 34       vintage        0.49
# 103          age        0.49
# 214       disney        0.44
# 441  collectible        0.44
# 2    manufacture        0.44
# 218          and        0.43
# 191            s        0.41

# %% [markdown]
# ## P&A

# %% [markdown]
# ### GPT

# %%
pna_gpt_with_forbidden = pd.read_parquet('data/Datasets/hag_pna_collct_09_24/GenSigsData/pna/pna_with_forbidden_gpt.parquet')
pna_gpt_no_forbidden = pd.read_parquet('data/Datasets/hag_pna_collct_09_24/GenSigsData/pna/pna_no_forbidden_gpt.parquet')

# %%
dists_with_forbidden = calc_words_frequency(pna_gpt_with_forbidden, 'gen_sig_gpt', density_as_perc=True)[:k_tokens][['Word', 'Density(%)']]
dists_with_forbidden
# Out:
#                Word  Density(%)
# 2          warranty        7.96
# 8               oem        4.19
# 32             year        3.59
# 31                1        3.57
# 7           genuine        3.35
# 24     manufacturer        2.54
# 9             brand        2.41
# 39            month        2.35
# 80          quality        2.09
# 79             high        1.94
# 30          limited        1.45
# 78                6        1.29
# 38               12        1.26
# 26      replacement        0.99
# 55               oe        0.91
# 188           years        0.88
# 189             and        0.80
# 25           direct        0.73
# 23         lifetime        0.59
# 51              100        0.55
# 132             new        0.55
# 68             part        0.53
# 176        material        0.53
# 92            steel        0.53
# 165             fit        0.52
# 77              day        0.51
# 99            parts        0.50
# 169               5        0.47
# ...

# %%
dists_no_forbidden = calc_words_frequency(pna_gpt_no_forbidden, 'gen_sig_gpt', density_as_perc=True)[:k_tokens][['Word', 'Density(%)']]
dists_no_forbidden
# Out:
#              Word  Density(%)
# 0           brand        7.36
# 26    aftermarket        5.12
# 37        branded        3.19
# 58             oe        2.41
# 8        material        1.28
# 88           type        1.27
# 38            oem        1.24
# 90          miles        1.10
# 107         steel        0.75
# 39          front        0.73
# 52             on        0.69
# 271           not        0.68
# 51      placement        0.66
# 254     available        0.66
# 62            and        0.64
# 5            ford        0.63
# 53        vehicle        0.57
# 6        aluminum        0.55
# 134          easy        0.53
# 154        dorman        0.53
# 160            of        0.53
# 135            to        0.49
# 140   performance        0.47
# 106     stainless        0.43
# 303  installation        0.41
# 54           rear        0.41
# 92           from        0.38
# 18             in        0.37
# 193           all        0.37
# 56          honda        0.36
# ...

# %%
pna_gpt_with_forbidden
# Out:
#            item_id                                          item_desc  \
# 0     116229424196  PG1ldGEgbmFtZT0ia2V5d29yZHMiIGNvbnRlbnQ9InVzZW...
# 1     126028451215  PGZvbnQgcndyPSIxIiBzdHlsZT0iIj48ZGl2IHN0eWxlPS...
# 2     134952985532  PCEtLSBEZXNjVGVtcGxhdGVJRDogRnJvbnQgQm9keSAoNj...
# 3     135211723255  PHN0eWxlPgogICAgQG1lZGlhIHNjcmVlbiBhbmQgKG1heC...
# 4     144432285379  PCEtLSBCRUdJTiBWSURFTyAtLT4KPGRpdiBjbGFzcz0iZn...
# ...            ...                                                ...
# 9981  394481992200  CiAgPCFET0NUWVBFIGh0bWw+CjxodG1sIGxhbmc9ImVuIj...
# 9982  395618655825  PG1ldGEgY2hhcnNldD0iVVRGLTgiPgo8bWV0YSBuYW1lPS...
# 9983  402382727509  CgkJCQkJICA8IURPQ1RZUEUgaHRtbD4KPGh0bWwgbGFuZz...
# 9984  405123346459  PCEtLXRvbmd0b29sLXJlbGF0ZWRDc3NTdGFydC0tPjxsaW...
# 9985  405191096532  PGh0bWw+Cgo8aGVhZD4KICAgIDxtZXRhIG5hbWU9InZpZX...
#
#                                                   title SUBTITLE  \
# ...

# %%
pna_gpt_with_forbidden['gen_sig_gpt'].str.lower().str.contains('warranty').mean()
# Out:
# 0.2635689965952333

# %%
pna_gpt_with_forbidden.loc[ pna_gpt_with_forbidden['gen_sig_gpt'].str.lower().str.contains('warranty') , ['item_id',  'gen_sig_gpt', 'title', 'aspects', 'desc' ]].\
to_csv('data/Datasets/hag_pna_collct_09_24/GenSigsData/pna/statistics_warranty.csv')

# %%
pna_gpt_with_forbidden.loc[ pna_gpt_with_forbidden['gen_sig_gpt'].str.lower().str.contains('warranty') , 'gen_sig_gpt'].value_counts()
# Out:
# gen_sig_gpt
# Limited 1 Year Warranty              447
# 12 Month Warranty                    388
# 1 Year Manufacturer Warranty         354
# 6 Month Warranty                     335
# 1 Year Warranty                      268
#                                     ...
# 3- Year Warranty                       1
# 1 Year Quality Warranty                1
# Five Year Warranty                     1
# 10-Year Warranty                       1
# 1-Year Unlimited-Mileage Warranty      1
# Name: count, Length: 125, dtype: int64

# %%
df = pd.read_parquet('data/Datasets/hag_pna_collct_09_24/GenSigsData/hag/hag_with_forbidden_gpt.parquet')
df1 = create_xsls_for_curators(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 df = pd.read_parquet('data/Datasets/hag_pna_collct_09_24/GenSigsData/hag/hag_with_forbidden_gpt.parquet')
# ----> 2 df1 = create_xsls_for_curators(df)
#
# NameError: name 'create_xsls_for_curators' is not defined

# %% [markdown]
# ## H&G

# %% [markdown]
# ### GPT

# %%
hag_gpt_with_forbidden = pd.read_parquet('data/Datasets/hag_pna_collct_09_24/GenSigsData/hag/hag_with_forbidden_gpt.parquet')
hag_gpt_no_forbidden = pd.read_parquet('data/Datasets/hag_pna_collct_09_24/GenSigsData/hag/hag_no_forbidden_gpt.parquet')

# %%
dists_with_forbidden = calc_words_frequency(hag_gpt_with_forbidden, 'gen_sig_gpt', density_as_perc=True)[:k_tokens][['Word', 'Density(%)']]
dists_with_forbidden
# Out:
#            Word  Density(%)
# 39     material        1.68
# 3          high        1.62
# 29          and        1.48
# 220         100        1.48
# 35      quality        1.44
# 181       steel        0.99
# 37      durable        0.92
# 180   stainless        0.73
# 318      cotton        0.71
# 57           in        0.65
# 155      design        0.63
# 104   resistant        0.63
# 240       brand        0.62
# 158        free        0.62
# 254          to        0.60
# 161     genuine        0.55
# 74          oem        0.52
# 47          new        0.50
# 197        with        0.47
# 67     warranty        0.46
# 322        easy        0.46
# 40         soft        0.45
# 58            1        0.42
# 16      premium        0.42
# 25      vintage        0.39
# 605  compatible        0.37
# 21     capacity        0.35
# 199           3        0.35
# 241   polyester        0.34
# 118        hand        0.34
# 100         non        0.33
# 270        wood        0.33
# ...

# %%
dists_no_forbidden = calc_words_frequency(hag_gpt_no_forbidden, 'gen_sig_gpt', density_as_perc=True)[:k_tokens][['Word', 'Density(%)']]
dists_no_forbidden
# Out:
#             Word  Density(%)
# 38      material        2.59
# 111        brand        1.45
# 73           and        1.23
# 180        steel        1.14
# 231          100        0.98
# 179    stainless        0.92
# 140          for        0.77
# 65            to        0.71
# 35        cotton        0.70
# 64          easy        0.66
# 322   compatible        0.64
# 23         power        0.60
# 69            in        0.59
# 156       design        0.56
# 194         with        0.48
# 444           of        0.48
# 36       durable        0.47
# 98      handmade        0.45
# 135         wood        0.43
# 234         wall        0.40
# 24           led        0.39
# 68             2        0.37
# 259      ceramic        0.36
# 125    resistant        0.35
# 100       united        0.34
# 60             4        0.34
# 19         style        0.33
# 657            3        0.33
# 101       states        0.33
# 41          soft        0.32
# 61             5        0.32
# ...

# %% [markdown]
# # Frequency of forbidden tokens

# %%
freqs = calc_forbid_words_frequencies(sigs_collct_with_forbidden_mistral, 'gen_sig_mistral')

# %%
freqs.iloc[:20]
# Out:
#       Forbidden Word  Count
# 112          vintage   1355
# 142        condition   1135
# 148         original    851
# 24                us    495
# 70               new    386
# 18         authentic    325
# 40           quality    306
# 61              rare    258
# 139             high    242
# 130           signed    187
# 72           limited    174
# 109          edition    173
# 104          antique    133
# 1    limited edition    122
# 97               old    118
# 38          shipping    118
# 117         official    116
# 8               used    109
# 26              free     95
# 75        officially     81

# %%
# Convert the 'gen_sig_mistral' column to lowercase
sigs_collct_with_forbidden_mistral['gen_sig_mistral_lower'] = sigs_collct_with_forbidden_mistral['gen_sig_mistral'].str.lower()

# Initialize a dictionary to store counts
word_counts = {word: 0 for word in forbidden_words}

# Count occurrences of each forbidden word
for word in forbidden_words:
    word_counts[word] = sigs_collct_with_forbidden_mistral['gen_sig_mistral_lower'].str.contains(word).sum()

# Create a DataFrame from the dictionary
result_df = pd.DataFrame(list(word_counts.items()), columns=['Forbidden Word', 'Count']).sort_values('Count', ascending = False)

# Display the result
print(result_df)
# Out:
#     Forbidden Word  Count
# 112        vintage   1355
# 142      condition   1135
# 148       original    851
# 24              us    495
# 70             new    386
# ..             ...    ...
# 111       whatsapp      0
# 28            help      0
# 74          paying      0
# 114         tiktok      0
# 59           cheap      0
#
# [153 rows x 2 columns]
